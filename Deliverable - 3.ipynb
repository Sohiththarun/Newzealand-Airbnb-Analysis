# %%
import pandas as pd

df = pd.read_csv("October_2025.csv")

df.head()
# Out:
#                     id                              name    host_id  \
# 0  1301058524473641980                        Lake house  664639500
# 1  1074933484046268258                      Rata Retreat  177030298
# 2  1075015563519391913                   Luxmore Heights  558111144
# 3  1046705564556087439  2 Bedrooms with Scenic Park View  462120635
# 4             40183765          Ensuite Cabin (Sleeps 6)   98758734
#
#                   host_name        neighbourhood_group  \
# 0                      John  Queenstown-Lakes District
# 1                    Twizel         Mackenzie District
# 2                    Raewyn         Southland District
# 3                    Prince                   Auckland
# 4  North South Holiday Park          Christchurch City
#
#               neighbourhood   latitude   longitude        room_type  price  \
# 0  Queenstown-Wakatipu Ward -45.030103  168.712810  Entire home/apt  900.0
# ...

# %%
df.head()
# Out:
#                     id                              name    host_id  \
# 0  1301058524473641980                        Lake house  664639500
# 1  1074933484046268258                      Rata Retreat  177030298
# 2  1075015563519391913                   Luxmore Heights  558111144
# 3  1046705564556087439  2 Bedrooms with Scenic Park View  462120635
# 4             40183765          Ensuite Cabin (Sleeps 6)   98758734
#
#                   host_name        neighbourhood_group  \
# 0                      John  Queenstown-Lakes District
# 1                    Twizel         Mackenzie District
# 2                    Raewyn         Southland District
# 3                    Prince                   Auckland
# 4  North South Holiday Park          Christchurch City
#
#               neighbourhood   latitude   longitude        room_type  price  \
# 0  Queenstown-Wakatipu Ward -45.030103  168.712810  Entire home/apt  900.0
# ...

# %%
df.shape
# Out:
# (47752, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47752 entries, 0 to 47751
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47752 non-null  int64
#  1   name                            47752 non-null  str
#  2   host_id                         47752 non-null  int64
#  3   host_name                       47738 non-null  str
#  4   neighbourhood_group             47752 non-null  str
#  5   neighbourhood                   47752 non-null  str
#  6   latitude                        47752 non-null  float64
#  7   longitude                       47752 non-null  float64
#  8   room_type                       47752 non-null  str
#  9   price                           45259 non-null  float64
#  10  minimum_nights                  47752 non-null  int64
#  11  number_of_reviews               47752 non-null  int64
# ...

# %% [markdown]
# Filter Christchurch ONLY

# %%
christchurch = df[
    df["neighbourhood_group"] == "Christchurch City"
].copy()

# %%
christchurch.head()
# Out:
#                      id                            name    host_id  \
# 4              40183765        Ensuite Cabin (Sleeps 6)   98758734
# 54  1149729199964166318  Handy city center. Simple room  298456605
# 69              1097487      Heritage Magic in Merivale    4993285
# 74  1339647508906377362         Settle into the sun set   54299306
# 76  1211070132323635531             Eco Spa-bath Studio  179297759
#
#                    host_name neighbourhood_group   neighbourhood   latitude  \
# 4   North South Holiday Park   Christchurch City   Harewood Ward -43.470020
# 54                      Tony   Christchurch City    Central Ward -43.532700
# 69                  Paulette   Christchurch City  Fendalton Ward -43.511490
# 74                    Sarena   Christchurch City    Burwood Ward -43.482864
# 76                      Peng   Christchurch City  Riccarton Ward -43.538437
#
#      longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %% [markdown]
# Add Month + Year

# %%
christchurch["month_year"] = "October 2025"

# %%
christchurch["month_year"].value_counts()
# Out:
# month_year
# October 2025    2991
# Name: count, dtype: int64

# %% [markdown]
# Check missing values

# %%
christchurch.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                              170
# minimum_nights                       0
# number_of_reviews                    0
# last_review                        307
# reviews_per_month                  307
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           2991
# month_year                           0
# dtype: int64

# %% [markdown]
# Check duplicates

# %%
christchurch.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Check data types

# %%
christchurch.dtypes
# Out:
# id                                  int64
# name                                  str
# host_id                             int64
# host_name                             str
# neighbourhood_group                   str
# neighbourhood                         str
# latitude                          float64
# longitude                         float64
# room_type                             str
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                           str
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                           float64
# month_year                            str
# dtype: object

# %%
christchurch["last_review"] = pd.to_datetime(
    christchurch["last_review"],
    errors="coerce"
)

# %% [markdown]
# Repeat for all 9 datasets

# %%
import pandas as pd

files = {
    "October 2025": "October_2025.csv",
    "November 2025": "November_2025.csv",
    "December 2025": "December_2025.csv",
    "January 2026": "January_2026.csv",
    "February 2026": "February_2026.csv",
    "March 2026": "March_2026.csv",
    "April 2026": "April_2026.csv",
    "May 2026": "May_2026.csv",
    "June 2026": "June 2026.csv"
}

# %%
all_christchurch = []

for month, file in files.items():

    # Load dataset
    data = pd.read_csv(file)

    # Filter Christchurch
    data = data[
        data["neighbourhood_group"] == "Christchurch City"
    ].copy()

    # Add month and year
    data["month_year"] = month

    # Convert date
    data["last_review"] = pd.to_datetime(
        data["last_review"],
        errors="coerce"
    )

    # Store processed dataset
    all_christchurch.append(data)

# %% [markdown]
# Concatenate the datasets

# %%
christchurch_all = pd.concat(
    all_christchurch,
    ignore_index=True
)

# %%
christchurch_all.shape
# Out:
# (28795, 19)

# %%
christchurch_all["month_year"].value_counts()
# Out:
# month_year
# June 2026        3469
# May 2026         3361
# April 2026       3273
# March 2026       3227
# February 2026    3190
# December 2025    3180
# January 2026     3057
# November 2025    3047
# October 2025     2991
# Name: count, dtype: int64

# %% [markdown]
# Check the final dataset

# %%
christchurch_all.head()
# Out:
#                     id                            name      host_id  \
# 0             40183765        Ensuite Cabin (Sleeps 6)   98758734.0
# 1  1149729199964166318  Handy city center. Simple room  298456605.0
# 2              1097487      Heritage Magic in Merivale    4993285.0
# 3  1339647508906377362         Settle into the sun set   54299306.0
# 4  1211070132323635531             Eco Spa-bath Studio  179297759.0
#
#                   host_name neighbourhood_group   neighbourhood   latitude  \
# 0  North South Holiday Park   Christchurch City   Harewood Ward -43.470020
# 1                      Tony   Christchurch City    Central Ward -43.532700
# 2                  Paulette   Christchurch City  Fendalton Ward -43.511490
# 3                    Sarena   Christchurch City    Burwood Ward -43.482864
# 4                      Peng   Christchurch City  Riccarton Ward -43.538437
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
christchurch_all.tail()
# Out:
#                         id                                              name  \
# 28790   847521223991840944                               City Park Townhouse
# 28791  1675859538548775874           Relaxing Christchurch Base near the CBD
# 28792  1701868509562071280  Unique central city standalone home with parking
# 28793  1361903004430574659                              Home in Central City
# 28794   993567873481058119      Sumner Beach, 2 blocks to the surf!\nMonthly
#
#             host_id            host_name neighbourhood_group   neighbourhood  \
# 28790  4.994250e+08                 Casa   Christchurch City    Central Ward
# 28791  3.317632e+08  Managed By Williams   Christchurch City    Central Ward
# 28792  1.673594e+18                 Mike   Christchurch City    Central Ward
# 28793  3.301075e+08               Nathan   Christchurch City    Central Ward
# 28794  4.359511e+06                Chris   Christchurch City  Heathcote Ward
#
# ...

# %%
christchurch_all.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'month_year'],
#       dtype='str')

# %%
christchurch_all.shape
# Out:
# (28795, 19)

# %%
christchurch_all["neighbourhood_group"].value_counts()
# Out:
# neighbourhood_group
# Christchurch City    28795
# Name: count, dtype: int64

# %% [markdown]
# Check duplicates

# %%
christchurch_all.duplicated().sum()
# Out:
# np.int64(0)

# %%
christchurch_all["id"].duplicated().sum()
# Out:
# np.int64(24678)

# %% [markdown]
# Summary statistics for numerical columns

# %%
numeric_summary = christchurch_all.describe().T

# %%
numeric_summary
# Out:
#                                   count                        mean  \
# id                              28795.0        903062686517304320.0
# host_id                         28795.0          1988281224095729.5
# latitude                        28795.0                  -43.555493
# longitude                       28795.0                  172.661295
# price                           18128.0                  260.199636
# minimum_nights                  28758.0                    1.787537
# number_of_reviews               28795.0                     70.3917
# last_review                       26168  2025-11-05 00:51:00.715377
# reviews_per_month               26168.0                    2.350719
# calculated_host_listings_count  28795.0                   58.297031
# availability_365                28795.0                  203.804792
# number_of_reviews_ltm           28795.0                   18.996909
# license                             0.0                         NaN
#
# ...

# %% [markdown]
# Categorical variables + counts

# %%
categorical_columns = christchurch_all.select_dtypes(
    include=["object"]
).columns

categorical_columns
# Out:
# C:\Users\sohit\AppData\Local\Temp\ipykernel_9056\23913830.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = christchurch_all.select_dtypes(
# Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'month_year'],
#       dtype='str')

# %%
christchurch_all["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    22765
# Private room        5744
# Hotel room           251
# Shared room           35
# Name: count, dtype: int64

# %%
christchurch_all["neighbourhood"].value_counts()
# Out:
# neighbourhood
# Central Ward            10554
# Banks Peninsula Ward     3548
# Heathcote Ward           2074
# Riccarton Ward           1885
# Fendalton Ward           1605
# Halswell Ward            1081
# Spreydon Ward            1056
# Innes Ward               1027
# Cashmere Ward            1009
# Harewood Ward             909
# Coastal Ward              891
# Waimairi Ward             883
# Linwood Ward              659
# Papanui Ward              648
# Hornby Ward               594
# Burwood Ward              372
# Name: count, dtype: int64

# %%
christchurch_all["month_year"].value_counts()
# Out:
# month_year
# June 2026        3469
# May 2026         3361
# April 2026       3273
# March 2026       3227
# February 2026    3190
# December 2025    3180
# January 2026     3057
# November 2025    3047
# October 2025     2991
# Name: count, dtype: int64

# %% [markdown]
# Create a general categorical summary

# %%
for col in categorical_columns:
    print("\n==============================")
    print(col)
    print("==============================")
    print(christchurch_all[col].value_counts(dropna=False).head(20))
# Out:
# ...
# name
# ...
# name
# Room in Christchurch                               23
# Waterfront 2-Bedroom Harbour View Apartment        20
# Home away from home.                               19
# Hagley Park Townhouse                              18
# cozycozy guest house                               18
# The City Sanctuary                                 18
# Modern King Studio | Netflix, Disney+ & Parking    18
# Spacious stylish home - 7 Night special deals      18
# Compact Studio with free Parking                   18
# Diamond Harbour Hideaway                           17
# Home away from home                                17
# Deluxe King Room                                   17
# Quite and Cozy Double Bedroom                      16
# City Townhouse                                     15
# Brand-New 1BR Apartment Near Upcoming Te Kaha      14
# Spacious studio                                    13
# The Hut                                            11
# ...

# %% [markdown]
# Missing-value summary

# %%
missing_summary = pd.DataFrame({
    "missing_count": christchurch_all.isnull().sum(),
    "missing_percentage": (
        christchurch_all.isnull().sum() /
        len(christchurch_all) * 100
    ).round(2)
})

missing_summary
# Out:
#                                 missing_count  missing_percentage
# id                                          0                0.00
# name                                        0                0.00
# host_id                                     0                0.00
# host_name                                   1                0.00
# neighbourhood_group                         0                0.00
# neighbourhood                               0                0.00
# latitude                                    0                0.00
# longitude                                   0                0.00
# room_type                                   0                0.00
# price                                   10667               37.04
# minimum_nights                             37                0.13
# number_of_reviews                           0                0.00
# last_review                              2627                9.12
# ...

# %% [markdown]
# Save the final concatenated dataset

# %%
import os

os.makedirs("output", exist_ok=True)

# %%
christchurch_all.to_csv(
    "output/Christchurch_listings_Oct2025_Jun2026.csv",
    index=False
)

# %% [markdown]
# Save your summary statistics too

# %%
numeric_summary.to_csv(
    "output/numerical_summary.csv"
)

# %%
missing_summary.to_csv(
    "output/missing_values_summary.csv"
)
